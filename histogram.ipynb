# %%
age=c(50,22,14,78,95,3,19,20,55,44,13,8,63,54,20)

# %%
hist(age,density=25,border="gray",col="hotpink",main="visualization of Age")
# Out:
# Plot with title "visualization of Age"

# %%
hist(age,border="black",col="hotpink",main="visualization of Age")
# Out:
# Plot with title "visualization of Age"

# %%
hist(age,border="black",col="skyblue",main="visualization of Age",breaks=10)
# Out:
# Plot with title "visualization of Age"
